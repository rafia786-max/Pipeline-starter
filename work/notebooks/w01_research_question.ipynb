# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rafia786-max/Pipeline-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My lane: Refresh / Content Opportunity Scoring
#
# I am choosing the Refresh / Content Opportunity Scoring lane. I want to investigate whether page-level search, engagement, content age, and freshness signals can help an SEO or content team decide which pages should be reviewed first. I chose this lane because the starter dataset contains 30,000 content items with trailing-90-day performance data, giving me several signals that may be useful for prioritization. This is a provisional choice, and I will use the next stages of the project to test whether the data supports this direction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## The question
#
# My research question is:
#
# **Can page-level search and engagement signals help rank content pages so that an SEO or content team can prioritize which pages should be reviewed first?**
#
# The decision is which pages should be reviewed first.
#
# An SEO or content reviewer would act on the output by inspecting the highest-priority pages and deciding whether each page should be refreshed, expanded, protected, pruned, or monitored.
#
# A wrong recommendation has two main costs. A false positive could waste limited reviewer time on a page that does not need attention. A false negative could cause an important page to be missed or reviewed too late.
#
# I will treat the output as a prioritization tool for human review, not as an automatic decision to change a page.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Quick look at the data
#
# I will first inspect the starter dataset and use a few real numbers to check whether this lane is worth investigating further.
# The starter dataset contains 30,000 content items and 44 columns. The median 90-day impressions are [731.0] and the median 90-day sessions are [7.0]. These numbers show that the dataset contains measurable differences in page visibility and engagement, making it reasonable to investigate whether these signals can help prioritize pages for review.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/rafia786-max/Pipeline-starter/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Dataset shape:", df.shape)
print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print("Median 90-day impressions:", df["impressions_90d"].median())
print("Median 90-day sessions:", df["sessions_90d"].median())
print("Median content age (days):", df["content_age_days"].median())
# Out:
# Dataset shape: (30000, 44)
# Number of rows: 30000
# Number of columns: 44
# Median 90-day impressions: 731.0
# Median 90-day sessions: 7.0
# Median content age (days): 236.0

# %% [markdown]
# ## Careful words
#
# I can investigate whether the available page-level signals contain useful information for prioritizing content pages for human review. I can measure and compare how different ranking approaches perform under a defined evaluation setup.
#
# I cannot claim that a highly ranked page definitely needs a refresh, or that refreshing a page will definitely increase its traffic, clicks, or rankings. I also cannot claim that the analysis proves that a particular signal causes a change in page performance.
#
# The results will be treated as directional and decision-support evidence. I will not claim to predict Google or provide causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
